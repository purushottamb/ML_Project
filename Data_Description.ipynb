# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from itertools import *
# %matplotlib inline

# %%
#Load Dataset
dataset = pd.read_csv('dataset.csv')
#split DV and IDVs
data = dataset.iloc[:,2:]
#X = dataset.iloc[:, 2:-1] # Features
#y = dataset.iloc[:, -1] # Target variable

# %%
data.head()
# Out:
#    age  Gender  Primary education  ...  own_phone  ppi_cutoff  active_dfs
# 0   15       0                  0  ...          1           0           1
# 1   55       1                  0  ...          0           0           1
# 2   62       1                  0  ...          1           0           1
# 3   26       1                  0  ...          1           1           1
# 4   39       1                  0  ...          1           1           1
#
# [5 rows x 11 columns]

# %%
#Data Dimensions
print ("Number of rows    :",data.shape[0])
print ("Number of columns :",data.shape[1])
# Out:
# Number of rows    : 175
# Number of columns : 11

# %%
#Data Information
print ("data info  :",data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  175 non-null    int64
#  1   Gender               175 non-null    int64
#  2   Primary education    175 non-null    int64
#  3   Secondary education  175 non-null    int64
#  4   Higher education     175 non-null    int64
#  5   UR                   175 non-null    int64
#  6   Literacy             175 non-null    int64
#  7   fn                   175 non-null    int64
#  8   own_phone            175 non-null    int64
#  9   ppi_cutoff           175 non-null    int64
#  10  active_dfs           175 non-null    int64
# dtypes: int64(11)
# memory usage: 15.2 KB
# data info  : None

# %%
#Missing values
print (data.isnull().sum())
# Out:
# age                    0
# Gender                 0
# Primary education      0
# Secondary education    0
# Higher education       0
# UR                     0
# Literacy               0
# fn                     0
# own_phone              0
# ppi_cutoff             0
# active_dfs             0
# dtype: int64

# %%
#Data Summary
plt.figure(figsize=(12,8))
sns.heatmap(data.describe()[1:].transpose(),
            annot=True,linecolor="w",
            linewidth=2,cmap=sns.color_palette("Set2"))
plt.title("Data summary")
plt.show()

# %%
# Correlation between Variables
correlation = data.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation,annot=True,
            cmap=sns.color_palette("magma"),
            linewidth=2,edgecolor="k")
plt.title("CORRELATION BETWEEN VARIABLES")
plt.show()

# %%
plt.figure(figsize=(12,6))

plt.subplot(122)
plt.pie(data["active_dfs"].value_counts().values,
        labels=["DFS","NO DFS"],
        autopct="%1.0f%%",wedgeprops={"linewidth":2,"edgecolor":"white"})
my_circ = plt.Circle((0,0),.7,color = "white")
plt.gca().add_artist(my_circ)
plt.subplots_adjust(wspace = .2)
plt.title("Proportion of target variable in dataset")
plt.show()
